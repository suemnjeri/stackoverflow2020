# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')

# %%
data = pd.read_csv('survey_results_public.csv')
data.shape
# Out:
# (64461, 61)

# %%
pd.set_option('display.max_rows', 65)
pd.set_option('display.max_columns', 65)

# %%
data.dtypes
# Out:
# Respondent                        int64
# MainBranch                       object
# Hobbyist                         object
# Age                             float64
# Age1stCode                       object
# CompFreq                         object
# CompTotal                       float64
# ConvertedComp                   float64
# Country                          object
# CurrencyDesc                     object
# CurrencySymbol                   object
# DatabaseDesireNextYear           object
# DatabaseWorkedWith               object
# DevType                          object
# EdLevel                          object
# Employment                       object
# Ethnicity                        object
# Gender                           object
# JobFactors                       object
# JobSat                           object
# JobSeek                          object
# LanguageDesireNextYear           object
# LanguageWorkedWith               object
# ...

# %%
schema = pd.read_csv('survey_results_schema.csv')
schema.shape
# Out:
# (61, 2)

# %%
schema
# Out:
#                           Column  \
# 0                     Respondent
# 1                     MainBranch
# 2                       Hobbyist
# 3                            Age
# 4                     Age1stCode
# 5                       CompFreq
# 6                      CompTotal
# 7                  ConvertedComp
# 8                        Country
# 9                   CurrencyDesc
# 10                CurrencySymbol
# 11        DatabaseDesireNextYear
# 12            DatabaseWorkedWith
# 13                       DevType
# 14                       EdLevel
# 15                    Employment
# 16                     Ethnicity
# 17                        Gender
# 18                    JobFactors
# 19                        JobSat
# 20                       JobSeek
# 21        LanguageDesireNextYear
# 22            LanguageWorkedWith
# 23        MiscTechDesireNextYear
# 24            MiscTechWorkedWith
# 25  NEWCollabToolsDesireNextYear
# 26      NEWCollabToolsWorkedWith
# ...

# %%
data.sample(5)
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 29605       29715                     I am a developer by profession      Yes
# 3082         3096                     I am a developer by profession      Yes
# 5285         5304             I am a student who is learning to code      Yes
# 14612       14658                     I am a developer by profession      Yes
# 3693         3708  I am not primarily a developer, but I write co...      Yes
#
#         Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 29605  21.0         13  Monthly    45000.0         8496.0  Russian Federation
# 3082   36.0         10   Yearly        NaN            NaN       United States
# 5285   18.0         12      NaN        NaN            NaN              Canada
# 14612  31.0         17   Yearly    40000.0        51704.0      United Kingdom
# 3693   24.0         13      NaN        NaN            NaN               Italy
#
# ...

# %%
data.hist(figsize=(10,10), xrot=45)
plt.show()

# %%
data.describe()
# Out:
#          Respondent           Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  64461.000000  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean   32554.079738     30.834111  3.190464e+242   1.037561e+05     40.782174
# std    18967.442360      9.585392            inf   2.268853e+05     17.816383
# min        1.000000      1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%    16116.000000     24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%    32231.000000     29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%    49142.000000     35.000000   1.250000e+05   9.500000e+04     44.000000
# max    65639.000000    279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
data.describe(include='object')
# Out:
#                             MainBranch Hobbyist Age1stCode CompFreq  \
# count                            64162    64416      57900    40069
# unique                               5        2         63        3
# top     I am a developer by profession      Yes         15   Yearly
# freq                             47193    50388       5618    19818
#
#               Country          CurrencyDesc CurrencySymbol  \
# count           64072                 45472          45472
# unique            183                   142            141
# top     United States  United States dollar            USD
# freq            12469                 11050          11050
#
#        DatabaseDesireNextYear DatabaseWorkedWith                DevType  \
# count                   44070              49537                  49370
# unique                   3193               2808                   8269
# top                PostgreSQL              MySQL  Developer, full-stack
# ...

# %%
categ_cols = data.select_dtypes('object')
less_than_10_categs = list(categ_cols.columns[data.select_dtypes('object').nunique() < 10])

# %%
for col in less_than_10_categs:
    sns.countplot(y = col, data=data)
    plt.show()

# %%
data.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
#      CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# ...

# %%
data[['DevType','Gender']].sample(60)
# Out:
#                                                  DevType  \
# 47078                              Developer, full-stack
# 60461                                                NaN
# 48757  Developer, back-end;Developer, desktop or ente...
# 26127                                                NaN
# 60051                                                NaN
# 46356  Data or business analyst;Database administrato...
# 62646                                                NaN
# 8024   Database administrator;Developer, back-end;Dev...
# 44766                                  Developer, mobile
# 58847  Developer, back-end;Developer, full-stack;Deve...
# 16861  Database administrator;Developer, back-end;Dev...
# 23938            Developer, full-stack;DevOps specialist
# 26939  Developer, back-end;Developer, front-end;Devel...
# 53004  Developer, back-end;Engineer, site reliability...
# 7488   Developer, embedded applications or devices;De...
# ...

# %%
data['DevType'].str.split(';').to_list()
# Out:
# [['Developer, desktop or enterprise applications', 'Developer, full-stack'],
#  ['Developer, full-stack', 'Developer, mobile'],
#  nan,
#  nan,
#  nan,
#  ['Designer', 'Developer, front-end', 'Developer, mobile'],
#  ['Developer, back-end',
#   'Developer, front-end',
#   'Developer, QA or test',
#   'DevOps specialist'],
#  ['Developer, back-end',
#   'Developer, desktop or enterprise applications',
#   'Developer, game or graphics'],
#  ['Developer, full-stack'],
#  ['Database administrator', 'Developer, full-stack', 'Developer, mobile'],
#  ['Developer, back-end',
#   'Developer, desktop or enterprise applications',
#   'Developer, embedded applications or devices',
#   'Developer, front-end'],
#  ['Designer', 'Developer, front-end'],
#  ['Designer', 'Developer, back-end'],
#  ['Developer, desktop or enterprise applications', 'Developer, front-end'],
#  nan,
#  ['Database administrator',
#   'Developer, back-end',
#   'Developer, desktop or enterprise applications',
# ...

# %%
type_lists = data['DevType'].str.split(';', expand=True).values.tolist()

# %%
single_dev_list = list(pd.core.common.flatten(type_lists))

# %%
from collections import Counter
Counter(single_dev_list)
# Out:
# Counter({'Developer, desktop or enterprise applications': 11784,
#          'Developer, full-stack': 27125,
#          None: 978416,
#          'Developer, mobile': 9482,
#          nan: 347093,
#          'Designer': 5321,
#          'Developer, front-end': 18296,
#          'Developer, back-end': 27228,
#          'Developer, QA or test': 3947,
#          'DevOps specialist': 5969,
#          'Developer, game or graphics': 2789,
#          'Database administrator': 5722,
#          'Developer, embedded applications or devices': 4750,
#          'Engineer, data': 3738,
#          'Educator': 2928,
#          'System administrator': 5242,
#          'Engineering manager': 2724,
#          'Product manager': 2497,
#          'Data or business analyst': 4024,
#          'Academic researcher': 3552,
#          'Data scientist or machine learning specialist': 3988,
#          'Scientist': 2086,
#          'Senior executive/VP': 1320,
#          'Engineer, site reliability': 1940,
# ...

# %%
dict_types = Counter(single_dev_list)
dict_types
# Out:
# Counter({'Developer, desktop or enterprise applications': 11784,
#          'Developer, full-stack': 27125,
#          None: 978416,
#          'Developer, mobile': 9482,
#          nan: 347093,
#          'Designer': 5321,
#          'Developer, front-end': 18296,
#          'Developer, back-end': 27228,
#          'Developer, QA or test': 3947,
#          'DevOps specialist': 5969,
#          'Developer, game or graphics': 2789,
#          'Database administrator': 5722,
#          'Developer, embedded applications or devices': 4750,
#          'Engineer, data': 3738,
#          'Educator': 2928,
#          'System administrator': 5242,
#          'Engineering manager': 2724,
#          'Product manager': 2497,
#          'Data or business analyst': 4024,
#          'Academic researcher': 3552,
#          'Data scientist or machine learning specialist': 3988,
#          'Scientist': 2086,
#          'Senior executive/VP': 1320,
#          'Engineer, site reliability': 1940,
# ...

# %%
dev_types_list = list(dict_types.keys())

# %%
dev_types_list
# Out:
# ['Developer, desktop or enterprise applications',
#  'Developer, full-stack',
#  None,
#  'Developer, mobile',
#  nan,
#  'Designer',
#  'Developer, front-end',
#  'Developer, back-end',
#  'Developer, QA or test',
#  'DevOps specialist',
#  'Developer, game or graphics',
#  'Database administrator',
#  'Developer, embedded applications or devices',
#  'Engineer, data',
#  'Educator',
#  'System administrator',
#  'Engineering manager',
#  'Product manager',
#  'Data or business analyst',
#  'Academic researcher',
#  'Data scientist or machine learning specialist',
#  'Scientist',
#  'Senior executive/VP',
#  'Engineer, site reliability',
#  'Marketing or sales professional']
