# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')

#Display more rows and columns
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %%
data = pd.read_csv('survey_results_public.csv')
schema = pd.read_csv('survey_results_schema.csv')
data.shape, schema.shape
# Out:
# ((64461, 61), (61, 2))

# %%
data.head(5)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
#      CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# ...

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Developer types
#
# Getting a list of all the developer types

# %%
data['DevType'].sample(20)
# Out:
# 15448    Data or business analyst;Data scientist or mac...
# 4222                                 Developer, full-stack
# 3628             Developer, back-end;Developer, full-stack
# 28668                                                  NaN
# 15897                                                  NaN
# 57556                                Developer, full-stack
# 11428                                                  NaN
# 43479                                Developer, full-stack
# 27527         DevOps specialist;Engineer, site reliability
# 11926    Developer, desktop or enterprise applications;...
# 49906                                  Developer, back-end
# 40899                                                  NaN
# 46320    Database administrator;Developer, back-end;Dev...
# 39632    Developer, back-end;Developer, front-end;Devel...
# 4437               Developer, full-stack;DevOps specialist
# 62888                                                  NaN
# ...

# %%
from collections import Counter

# %%
def unlock_devtypes(df, column):
    respondent_lists = df[column].str.split(';', expand=True).values.tolist()
    flat_lists = list(pd.core.common.flatten(respondent_lists))
    type_count_dict = Counter(flat_lists)
    unique_types_list = list(type_count_dict.keys())
    
    #drop None and nan
    for i in [2,3]:
        unique_types_list.pop(i)
        
    return unique_types_list

# %%
unique_types = unlock_devtypes(data, 'DevType')
len(unique_types)

# %%
def create_devtype_columns(df, dev_list, column):
    #include doc string
    
    #Loop through the list of types
    for i in range(0, len(dev_list)):
        new_col = dev_list[i]
        df[new_col] = 0 
        # for every row, replace the column value with 1 if the type is present in 'DevType' column
        df.loc[df[column].str.contains(new_col, na=False), new_col] = 1 
        
    #create a new column called 'total_types'
    #sum up all the 1s in the new columns created above to get how many dev types each person works with
    #df['total_types'] = df.iloc[:, 61:].sum(axis=1)
    df['total_types'] = df[dev_list].sum(axis=1)
    
    return df

# %%
data2 = create_devtype_columns(data, unique_types, 'DevType')

# %% [markdown]
# ## Age: Remove rows without Age data

# %%
missing_to_drop = ['Age', 'Age1stCode', 'YearsCode']

# %%
data2.dropna(subset=missing_to_drop)

# %% [markdown]
# #functions
#
# 1. drop na subset
# 2. replace values and convert years column to float (yearsCode, yearscodepro, age1stcode)
# 3. clean age column (remove over 75 and under 10)

# %% [markdown]
# #create new columns
# 1. years_to_pro
# 2. age_active_code
# 3. age_group_active

# %%
#dr

# %% [markdown]
# ### Modify the dataset by adding a new column for every devtype (23 columns in total added)
# Loop through the list we have created above.
#
# For every list value (type) above, create a new column with that value's name and fill it with zeros. Then check the dataset's rows to see if the 'DevType' column contains that list value.
#
# If the list value is present in the 'DevType' column, change the value of the new column with that name (the list value) to 1.
#
# For example, if you are on the 4th loop -list value is 'Designer'-, create a new column called 'Designer' and fill it with 0s. Then check the rows and if you come across one where one of the options chosen by a respondent was 'Designer', then in the new 'Designer' column replace the 0 value with 1.

# %% [markdown]
# ### Get our dataset of interest - age
#
# Remove all rows where the respondent did not fill in the columns we will be interested in this project; Current age, the age they wrote their first line of code, and the years they have been actively coding, including in school.

# %%
data.to_csv('SO_devtypes_part1.csv', index=False)

# %%
data.shape
# Out:
# (64461, 85)

# %%
data_age = data.dropna(subset=['Age', 'Age1stCode', 'YearsCode'])

# %%
data_age.shape
# Out:
# (45178, 85)

# %%
data.describe(include='object')
# Out:
#                             MainBranch Hobbyist Age1stCode CompFreq  \
# count                            64162    64416      57900    40069
# unique                               5        2         63        3
# top     I am a developer by profession      Yes         15   Yearly
# freq                             47193    50388       5618    19818
#
#               Country          CurrencyDesc CurrencySymbol  \
# count           64072                 45472          45472
# unique            183                   142            141
# top     United States  United States dollar            USD
# freq            12469                 11050          11050
#
#        DatabaseDesireNextYear DatabaseWorkedWith                DevType  \
# count                   44070              49537                  49370
# unique                   3193               2808                   8269
# top                PostgreSQL              MySQL  Developer, full-stack
# ...

# %%
data_age.sample(3)
# Out:
#        Respondent                              MainBranch Hobbyist   Age  \
# 26931       27030          I am a developer by profession      Yes  32.0
# 10554       10588          I am a developer by profession       No  27.0
# 16536       16594  I am a student who is learning to code      Yes  16.0
#
#       Age1stCode CompFreq  CompTotal  ConvertedComp  Country  \
# 26931         11  Monthly        NaN            NaN  Belarus
# 10554         19  Monthly        NaN            NaN    India
# 16536         11      NaN        NaN            NaN   Serbia
#
#                CurrencyDesc CurrencySymbol  \
# 26931  United States dollar            USD
# 10554          Indian rupee            INR
# 16536                   NaN            NaN
#
#                                   DatabaseDesireNextYear  \
# 26931                                                NaN
# 10554                       Firebase;MySQL;Oracle;SQLite
# 16536  Firebase;Microsoft SQL Server;MySQL;Oracle;SQLite
#
# ...

# %%
data_age.to_csv('SO_age.csv', index=False)
